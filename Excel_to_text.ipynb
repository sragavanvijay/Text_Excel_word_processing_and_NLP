# %%
import xlrd
import csv
import pandas as pd

# %%
# !la /home/jovyan/Sample_doc/Woolies/
# Out:
# /bin/sh: 1: la: not found

# %%
tab1 = pd.read_excel('/home/jovyan/New_client1/Clarence_Street_Funding.xlsx', index_col=None,
                  sheetname ='BS notes')

# %%
tab1
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 0                                                  NaN         NaN
# 1                        4.  CASH AND CASH EQUIVALENTS         NaN
# 2                                                  NaN         NaN
# 3                                        Bank Balances         NaN
# 4                                        Term deposits         NaN
# 5                                                  NaN         NaN
# 6                                                  NaN         NaN
# 7                                                  NaN         NaN
# 8                      5.  TRADE AND OTHER RECEIVABLES         NaN
# 9                                                  NaN         NaN
# 10                                          GST refund         NaN
# 11                          Owing from related parties         NaN
# 12                                   Sundry receivable         NaN
# ...

# %%
tab1.to_csv('Excel_BS_notes.txt', index=False, sep='\t', encoding='utf-8',line_terminator='\n')

# %%
# Out:
# None
